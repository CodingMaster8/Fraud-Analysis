# %%
import sys
from pathlib import Path
import pprint
import asyncio

# Get the notebook's directory and navigate up to the project root
notebook_dir = Path().resolve()
project_root = notebook_dir.parent  # Goes up two levels 

# Add project root to Python path if not already there
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
from src.traditional_cv import AnalysisConfig, AnomalyAnalyzer, AnalysisResult

# %%
config = AnalysisConfig()

# %%
pipeline = AnomalyAnalyzer(config=config)

# %%
result = pipeline.analyze_image("/Users/Pablo.Vargas2/Documents/isitreal-pablo/data/fraudulent/tipex_2.jpg")

# %%
result

# %%
print(result.whiteout_metrics)

# %%
result.overall_score

# %%
result.fraud_likelihood
