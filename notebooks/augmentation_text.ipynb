# %%
import sys
from pathlib import Path
import pprint
import asyncio

# Get the notebook's directory and navigate up to the project root
notebook_dir = Path().resolve()
project_root = notebook_dir.parent  # Goes up two levels 

# Add project root to Python path if not already there
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
from src.augmentation import AugmentationConfig, GeometricOnlyPipeline

# %%
config = AugmentationConfig(
    rotation_range=(-15, 15),
    scale_range=(0.9, 1.1),
    noise_level=(0.05, 0.2),
    brightness_range=(0.8, 1.2),
    contrast_range=(0.8, 1.2),
)

# %%
pipeline = GeometricOnlyPipeline(augmentation_config=config)

# %%
pipeline.process_dataset()

# %% [markdown]
# ## STATS

# %%
from src.augmentation import visualize_sample_augmentations, augmentation_stats

# %%
visualize_sample_augmentations(num_samples=6)

# %%
augmentation_stats()
